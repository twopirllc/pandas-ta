# %% [markdown]
# # Indicator Speed Test
#
# This Notebook shows the speed of each indicator _with_ and _without_ TA Lib
# * Results may vary if ```vectorbt``` or ```numba``` is installed.
# * These values are based on a M1 Macbook with 16GB Memory.

# %%
from importlib.util import find_spec

from numpy import version as numpy_version
from pandas import DataFrame, IndexSlice, concat, read_csv, __version__
from pandas import IndexSlice as idx
import pandas_ta as ta

print("Package Versions:")
print(f"Pandas v{__version__}")
print(f"Pandas TA v{ta.version}")

has_numba = find_spec("numba") is not None
if has_numba:
    from numba import __version__ as numba_version
    print(f"Numba v{numba_version}")
    
if find_spec("talib") is not None:
    from talib import __version__ as tal_version
    print(f"talib v{tal_version}")

from pandas import read_csv
from pandas import DatetimeIndex as dti
# %matplotlib inline
# Out:
# Package Versions:
# Pandas v2.2.0
# Pandas TA v0.4.12b0
# Numba v0.59.0
# talib v0.4.28

# %% [markdown]
# ### Fetch Sample Data

# %%
df = DataFrame()
_df = df.ta.ticker("SPY", period="5y", timed=True)
# Out:
# [+] yf | SPY(1260, 8): 1809.2097 ms (1.8092 s)

# %%
df = _df.copy()
df.shape
# Out:
# (1260, 8)

# %% [markdown]
# ### If ```numba``` installed, prep @njit functions
# * Some indicators like **ha** have numba/njit versions, so they need to be compiled by have a prerun. In the performance tests after this, **ha** and other numba/njit versions will be quicker also.

# %%
if has_numba:
    ta.speed_test(df.iloc[-150:], talib=False, silent=True)

# %% [markdown]
# ## Performance **without** TA Lib

# %%
pta_speedsdf, pta_statsdf = ta.speed_test(df, top=10, talib=False, stats=True, gradient=True, verbose=True)
# Out:
# [+] aberration: 0.8624 ms (0.0009 s)
# [+] accbands: 0.8761 ms (0.0009 s)
# [+] ad: 0.6500 ms (0.0006 s)
# [+] adosc: 1.3045 ms (0.0013 s)
# [+] adx: 2.8430 ms (0.0028 s)
# [+] alligator: 47.1401 ms (0.0471 s)
# [+] alma: 0.8818 ms (0.0009 s)
# [+] alphatrend: 3.6487 ms (0.0036 s)
# [+] amat: 1.8549 ms (0.0019 s)
# [+] ao: 0.4091 ms (0.0004 s)
# [+] aobv: 2.7360 ms (0.0027 s)
# [+] apo: 0.9364 ms (0.0009 s)
# [+] aroon: 5.2525 ms (0.0053 s)
# [+] atr: 1.3398 ms (0.0013 s)
# [+] atrts: 1.8064 ms (0.0018 s)
# [+] bbands: 1.0628 ms (0.0011 s)
# [+] bias: 0.6855 ms (0.0007 s)
# [+] bop: 0.5835 ms (0.0006 s)
# [+] brar: 1.7600 ms (0.0018 s)
# [+] cci: 13.1447 ms (0.0131 s)
# [+] cdl_pattern: 6.2703 ms (0.0063 s)
# [+] cdl_z: 1.2462 ms (0.0012 s)
# [+] cfo: 0.2802 ms (0.0003 s)
# [+] cg: 6.4479 ms (0.0064 s)
# [+] chandelier_exit: 2.3593 ms (0.0024 s)
# [+] chop: 0.8472 ms (0.0008 s)
# [+] cksp: 1.0035 ms (0.0010 s)
# [+] cmf: 0.7444 ms (0.0007 s)
# [+] cmo: 0.9773 ms (0.0010 s)
# [+] coppock: 0.2668 ms (0.0003 s)
# [+] crsi: 2.2293 ms (0.0022 s)
# [+] cti: 15.2671 ms (0.0153 s)
# [+] cube: 0.4808 ms (0.0005 s)
# [+] decay: 0.1362 ms (0.0001 s)
# [+] decreasing: 0.2167 ms (0.0002 s)
# [+] dema: 0.5917 ms (0.0006 s)
# [+] dm: 1.5374 ms (0.0015 s)
# [+] donchian: 0.5791 ms (0.0006 s)
# [+] dpo: 0.2641 ms (0.0003 s)
# [+] ebsw: 32.3526 ms (0.0324 s)
# [+] efi: 0.2988 ms (0.0003 s)
# [+] ema: 0.2940 ms (0.0003 s)
# [+] entropy: 0.4258 ms (0.0004 s)
# [+] eom: 0.7121 ms (0.0007 s)
# [+] er: 0.3142 ms (0.0003 s)
# [+] eri: 0.4772 ms (0.0005 s)
# [+] exhc: 0.2422 ms (0.0002 s)
# [+] fisher: 4.2052 ms (0.0042 s)
# [+] fwma: 1.2505 ms (0.0013 s)
# [+] ha: 0.4388 ms (0.0004 s)
# [+] hilo: 32.7702 ms (0.0328 s)
# [+] hl2: 0.3229 ms (0.0003 s)
# [+] hlc3: 0.2713 ms (0.0003 s)
# [+] hma: 0.3373 ms (0.0003 s)
# [+] ht_trendline: 0.3456 ms (0.0003 s)
# [+] hwc: 11.7341 ms (0.0117 s)
# [+] hwma: 5.3421 ms (0.0053 s)
# [+] ifisher: 0.4440 ms (0.0004 s)
# [+] increasing: 0.2562 ms (0.0003 s)
# [+] inertia: 1.6177 ms (0.0016 s)
# [+] jma: 24.5618 ms (0.0246 s)
# [+] kama: 4.5925 ms (0.0046 s)
# [+] kc: 0.7386 ms (0.0007 s)
# [+] kdj: 1.5595 ms (0.0016 s)
# [+] kst: 1.4076 ms (0.0014 s)
# [+] kurtosis: 0.2708 ms (0.0003 s)
# [+] kvo: 2.1295 ms (0.0021 s)
# [+] linreg: 12.0940 ms (0.0121 s)
# [+] log_return: 0.2841 ms (0.0003 s)
# [+] long_run: 0.0014 ms (0.0000 s)
# [+] macd: 1.7334 ms (0.0017 s)
# [+] mad: 12.7495 ms (0.0127 s)
# [+] mama: 0.3669 ms (0.0004 s)
# [+] massi: 0.9844 ms (0.0010 s)
# [+] mcgd: 1.7720 ms (0.0018 s)
# [+] median: 0.6321 ms (0.0006 s)
# [+] mfi: 0.4535 ms (0.0005 s)
# [+] midpoint: 0.3662 ms (0.0004 s)
# [+] midprice: 0.4199 ms (0.0004 s)
# [+] mom: 0.1270 ms (0.0001 s)
# [+] natr: 1.5981 ms (0.0016 s)
# [+] nvi: 1.2930 ms (0.0013 s)
# [+] obv: 0.7807 ms (0.0008 s)
# [+] ohlc4: 0.3358 ms (0.0003 s)
# [+] pdist: 0.8378 ms (0.0008 s)
# [+] percent_return: 0.1432 ms (0.0001 s)
# [+] pgo: 0.5018 ms (0.0005 s)
# [+] pivots: 9.0812 ms (0.0091 s)
# [+] ppo: 1.4622 ms (0.0015 s)
# [+] psar: 42.8820 ms (0.0429 s)
# [+] psl: 0.6870 ms (0.0007 s)
# [+] pvi: 1.2176 ms (0.0012 s)
# [+] pvo: 0.4860 ms (0.0005 s)
# [+] pvol: 0.2122 ms (0.0002 s)
# [+] pvr: 0.9285 ms (0.0009 s)
# [+] pvt: 0.2820 ms (0.0003 s)
# [+] pwma: 1.2252 ms (0.0012 s)
# [+] qqe: 76.1423 ms (0.0761 s)
# [+] qstick: 0.5799 ms (0.0006 s)
# [+] quantile: 0.6063 ms (0.0006 s)
# [+] reflex: 0.1597 ms (0.0002 s)
# [+] remap: 0.1209 ms (0.0001 s)
# [+] rma: 0.1615 ms (0.0002 s)
# [+] roc: 0.1135 ms (0.0001 s)
# [+] rsi: 0.8457 ms (0.0008 s)
# [+] rsx: 6.2984 ms (0.0063 s)
# [+] rvgi: 3.9946 ms (0.0040 s)
# [+] rvi: 1.4539 ms (0.0015 s)
# [+] rwi: 1.6562 ms (0.0017 s)
# [+] short_run: 0.0011 ms (0.0000 s)
# [+] sinwma: 17.4577 ms (0.0175 s)
# [+] skew: 0.2025 ms (0.0002 s)
# [+] slope: 0.1285 ms (0.0001 s)
# [+] sma: 0.3453 ms (0.0003 s)
# [+] smi: 0.9188 ms (0.0009 s)
# [+] smma: 15.1133 ms (0.0151 s)
# [+] squeeze: 2.0582 ms (0.0021 s)
# [+] squeeze_pro: 3.3051 ms (0.0033 s)
# [+] ssf: 0.1588 ms (0.0002 s)
# [+] ssf3: 0.1408 ms (0.0001 s)
# [+] stc: 37.8693 ms (0.0379 s)
# [+] stdev: 0.3233 ms (0.0003 s)
# [+] stoch: 1.7133 ms (0.0017 s)
# [+] stochf: 1.2160 ms (0.0012 s)
# [+] stochrsi: 0.8076 ms (0.0008 s)
# [+] supertrend: 16.8706 ms (0.0169 s)
# [+] swma: 1.2157 ms (0.0012 s)
# [+] t3: 1.4273 ms (0.0014 s)
# [+] tema: 0.7380 ms (0.0007 s)
# [+] thermo: 0.9419 ms (0.0009 s)
# [+] tmo: 0.8521 ms (0.0009 s)
# [+] tos_stdevall: 1.5836 ms (0.0016 s)
# [+] trendflex: 0.1590 ms (0.0002 s)
# [+] trima: 0.6093 ms (0.0006 s)
# [+] trix: 1.2614 ms (0.0013 s)
# [+] true_range: 0.9694 ms (0.0010 s)
# [+] tsi: 1.2655 ms (0.0013 s)
# [+] tsignals: 0.0011 ms (0.0000 s)
# [+] ttm_trend: 1.1507 ms (0.0012 s)
# [+] ui: 0.4515 ms (0.0005 s)
# [+] uo: 2.0976 ms (0.0021 s)
# [+] variance: 0.1966 ms (0.0002 s)
# [+] vhf: 0.6991 ms (0.0007 s)
# [+] vhm: 0.6778 ms (0.0007 s)
# [+] vidya: 34.1496 ms (0.0341 s)
# [+] vortex: 0.8700 ms (0.0009 s)
# [+] vwap: 8.5635 ms (0.0086 s)
# [+] vwma: 0.3592 ms (0.0004 s)
# [+] wb_tsv: 1.6159 ms (0.0016 s)
# [+] wcp: 0.2637 ms (0.0003 s)
# [+] willr: 0.5554 ms (0.0006 s)
# [+] wma: 0.2305 ms (0.0002 s)
# [+] xsignals: 0.0015 ms (0.0000 s)
# [+] zlma: 0.4540 ms (0.0005 s)
# [+] zscore: 0.7855 ms (0.0008 s)
#
# ============================================================
#   Slowest 10 Indicators [155]
#   Observations: 1260
# ============================================================
#                  ms     secs
# Indicator
# qqe         76.1423  0.07614
# alligator   47.1401  0.04714
# psar        42.8820  0.04288
# stc         37.8693  0.03787
# vidya       34.1496  0.03415
# hilo        32.7702  0.03277
# ebsw        32.3526  0.03235
# jma         24.5618  0.02456
# sinwma      17.4577  0.01746
# supertrend  16.8706  0.01687
#
# ============================================================
# Time Stats:
#                ms      secs
# min      0.001100  0.000000
# 50%      0.852100  0.000850
# mean     3.948935  0.003949
# max     76.142300  0.076140
# total  612.085000  0.612100
#
# ============================================================

# %%
pta_speedsdf
# Out:
# <style type="text/css">
# #T_7bae7_row0_col0, #T_7bae7_row0_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_7bae7_row1_col0, #T_7bae7_row1_col1 {
#   background-color: #ff7d00;
#   color: #f1f1f1;
# }
# #T_7bae7_row2_col0, #T_7bae7_row2_col1 {
#   background-color: #ff8f00;
#   color: #000000;
# }
# #T_7bae7_row3_col0, #T_7bae7_row3_col1 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_7bae7_row4_col0, #T_7bae7_row4_col1 {
#   background-color: #ffb500;
#   color: #000000;
# }
# #T_7bae7_row5_col0, #T_7bae7_row5_col1 {
#   background-color: #ffbb00;
#   color: #000000;
# }
# #T_7bae7_row6_col0, #T_7bae7_row6_col1 {
#   background-color: #ffbd00;
#   color: #000000;
# }
# #T_7bae7_row7_col0, #T_7bae7_row7_col1 {
#   background-color: #ffde00;
#   color: #000000;
# }
# #T_7bae7_row8_col0, #T_7bae7_row8_col1 {
#   background-color: #fffd00;
#   color: #000000;
# }
# #T_7bae7_row9_col0, #T_7bae7_row9_col1 {
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_7bae7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bae7_level0_col0" class="col_heading level0 col0" >ms</th>
#       <th id="T_7bae7_level0_col1" class="col_heading level0 col1" >secs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bae7_level0_row0" class="row_heading level0 row0" >qqe</th>
#       <td id="T_7bae7_row0_col0" class="data row0 col0" >76.142300</td>
#       <td id="T_7bae7_row0_col1" class="data row0 col1" >0.076140</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row1" class="row_heading level0 row1" >alligator</th>
#       <td id="T_7bae7_row1_col0" class="data row1 col0" >47.140100</td>
#       <td id="T_7bae7_row1_col1" class="data row1 col1" >0.047140</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row2" class="row_heading level0 row2" >psar</th>
#       <td id="T_7bae7_row2_col0" class="data row2 col0" >42.882000</td>
#       <td id="T_7bae7_row2_col1" class="data row2 col1" >0.042880</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row3" class="row_heading level0 row3" >stc</th>
#       <td id="T_7bae7_row3_col0" class="data row3 col0" >37.869300</td>
#       <td id="T_7bae7_row3_col1" class="data row3 col1" >0.037870</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row4" class="row_heading level0 row4" >vidya</th>
#       <td id="T_7bae7_row4_col0" class="data row4 col0" >34.149600</td>
#       <td id="T_7bae7_row4_col1" class="data row4 col1" >0.034150</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row5" class="row_heading level0 row5" >hilo</th>
#       <td id="T_7bae7_row5_col0" class="data row5 col0" >32.770200</td>
#       <td id="T_7bae7_row5_col1" class="data row5 col1" >0.032770</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row6" class="row_heading level0 row6" >ebsw</th>
#       <td id="T_7bae7_row6_col0" class="data row6 col0" >32.352600</td>
#       <td id="T_7bae7_row6_col1" class="data row6 col1" >0.032350</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row7" class="row_heading level0 row7" >jma</th>
#       <td id="T_7bae7_row7_col0" class="data row7 col0" >24.561800</td>
#       <td id="T_7bae7_row7_col1" class="data row7 col1" >0.024560</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row8" class="row_heading level0 row8" >sinwma</th>
#       <td id="T_7bae7_row8_col0" class="data row8 col0" >17.457700</td>
#       <td id="T_7bae7_row8_col1" class="data row8 col1" >0.017460</td>
#     </tr>
#     <tr>
#       <th id="T_7bae7_level0_row9" class="row_heading level0 row9" >supertrend</th>
#       <td id="T_7bae7_row9_col0" class="data row9 col0" >16.870600</td>
#       <td id="T_7bae7_row9_col1" class="data row9 col1" >0.016870</td>
#     </tr>
#   </tbody>
# </table>

# %%
pta_statsdf
# Out:
#                ms      secs
# min      0.001100  0.000000
# 50%      0.852100  0.000850
# mean     3.948935  0.003949
# max     76.142300  0.076140
# total  612.085000  0.612100

# %% [markdown]
# ## Performance **with** TA Lib

# %%
tal_speedsdf, tal_statsdf = ta.speed_test(df, top=10, talib=True, stats=True, gradient=True, verbose=True)
# Out:
# [+] aberration: 1.4520 ms (0.0015 s)
# [+] accbands: 1.6774 ms (0.0017 s)
# [+] ad: 0.5130 ms (0.0005 s)
# [+] adosc: 0.3955 ms (0.0004 s)
# [+] adx: 2.6092 ms (0.0026 s)
# [+] alligator: 47.4284 ms (0.0474 s)
# [+] alma: 0.6385 ms (0.0006 s)
# [+] alphatrend: 1.1714 ms (0.0012 s)
# [+] amat: 1.5313 ms (0.0015 s)
# [+] ao: 0.4211 ms (0.0004 s)
# [+] aobv: 2.6209 ms (0.0026 s)
# [+] apo: 0.2004 ms (0.0002 s)
# [+] aroon: 0.4581 ms (0.0005 s)
# [+] atr: 0.3622 ms (0.0004 s)
# [+] atrts: 0.4910 ms (0.0005 s)
# [+] bbands: 0.5894 ms (0.0006 s)
# [+] bias: 0.2355 ms (0.0002 s)
# [+] bop: 0.3610 ms (0.0004 s)
# [+] brar: 1.8524 ms (0.0019 s)
# [+] cci: 0.3212 ms (0.0003 s)
# [+] cdl_pattern: 6.7838 ms (0.0068 s)
# [+] cdl_z: 1.2919 ms (0.0013 s)
# [+] cfo: 0.2796 ms (0.0003 s)
# [+] cg: 6.4199 ms (0.0064 s)
# [+] chandelier_exit: 1.3723 ms (0.0014 s)
# [+] chop: 0.8248 ms (0.0008 s)
# [+] cksp: 0.9878 ms (0.0010 s)
# [+] cmf: 0.7575 ms (0.0008 s)
# [+] cmo: 0.1677 ms (0.0002 s)
# [+] coppock: 0.2570 ms (0.0003 s)
# [+] crsi: 0.7928 ms (0.0008 s)
# [+] cti: 15.3639 ms (0.0154 s)
# [+] cube: 0.4712 ms (0.0005 s)
# [+] decay: 0.1336 ms (0.0001 s)
# [+] decreasing: 0.2199 ms (0.0002 s)
# [+] dema: 0.1461 ms (0.0001 s)
# [+] dm: 0.3480 ms (0.0003 s)
# [+] donchian: 0.5668 ms (0.0006 s)
# [+] dpo: 0.2609 ms (0.0003 s)
# [+] ebsw: 32.8209 ms (0.0328 s)
# [+] efi: 0.3015 ms (0.0003 s)
# [+] ema: 0.1321 ms (0.0001 s)
# [+] entropy: 0.4190 ms (0.0004 s)
# [+] eom: 0.7204 ms (0.0007 s)
# [+] er: 0.3111 ms (0.0003 s)
# [+] eri: 0.4754 ms (0.0005 s)
# [+] exhc: 0.2393 ms (0.0002 s)
# [+] fisher: 4.2469 ms (0.0042 s)
# [+] fwma: 1.2835 ms (0.0013 s)
# [+] ha: 0.4299 ms (0.0004 s)
# [+] hilo: 32.5812 ms (0.0326 s)
# [+] hl2: 0.1958 ms (0.0002 s)
# [+] hlc3: 0.2522 ms (0.0003 s)
# [+] hma: 0.2930 ms (0.0003 s)
# [+] ht_trendline: 0.2998 ms (0.0003 s)
# [+] hwc: 11.4790 ms (0.0115 s)
# [+] hwma: 5.3904 ms (0.0054 s)
# [+] ifisher: 0.4065 ms (0.0004 s)
# [+] increasing: 0.2175 ms (0.0002 s)
# [+] inertia: 1.5922 ms (0.0016 s)
# [+] jma: 25.0673 ms (0.0251 s)
# [+] kama: 4.9924 ms (0.0050 s)
# [+] kc: 0.7583 ms (0.0008 s)
# [+] kdj: 1.0338 ms (0.0010 s)
# [+] kst: 0.9709 ms (0.0010 s)
# [+] kurtosis: 0.2154 ms (0.0002 s)
# [+] kvo: 1.8628 ms (0.0019 s)
# [+] linreg: 0.1584 ms (0.0002 s)
# [+] log_return: 0.1518 ms (0.0002 s)
# [+] long_run: 0.0010 ms (0.0000 s)
# [+] macd: 0.3461 ms (0.0003 s)
# [+] mad: 12.6799 ms (0.0127 s)
# [+] mama: 0.3712 ms (0.0004 s)
# [+] massi: 0.5951 ms (0.0006 s)
# [+] mcgd: 1.7917 ms (0.0018 s)
# [+] median: 0.6277 ms (0.0006 s)
# [+] mfi: 0.3785 ms (0.0004 s)
# [+] midpoint: 0.1389 ms (0.0001 s)
# [+] midprice: 0.1962 ms (0.0002 s)
# [+] mom: 0.1234 ms (0.0001 s)
# [+] natr: 0.2719 ms (0.0003 s)
# [+] nvi: 1.3096 ms (0.0013 s)
# [+] obv: 0.2220 ms (0.0002 s)
# [+] ohlc4: 0.3267 ms (0.0003 s)
# [+] pdist: 0.9833 ms (0.0010 s)
# [+] percent_return: 0.1630 ms (0.0002 s)
# [+] pgo: 0.5245 ms (0.0005 s)
# [+] pivots: 9.1797 ms (0.0092 s)
# [+] ppo: 0.6126 ms (0.0006 s)
# [+] psar: 45.4192 ms (0.0454 s)
# [+] psl: 0.8661 ms (0.0009 s)
# [+] pvi: 1.3073 ms (0.0013 s)
# [+] pvo: 0.5056 ms (0.0005 s)
# [+] pvol: 0.2196 ms (0.0002 s)
# [+] pvr: 0.9811 ms (0.0010 s)
# [+] pvt: 0.2975 ms (0.0003 s)
# [+] pwma: 1.3154 ms (0.0013 s)
# [+] qqe: 77.5280 ms (0.0775 s)
# [+] qstick: 0.3504 ms (0.0004 s)
# [+] quantile: 0.6113 ms (0.0006 s)
# [+] reflex: 0.1622 ms (0.0002 s)
# [+] remap: 0.1189 ms (0.0001 s)
# [+] rma: 0.1654 ms (0.0002 s)
# [+] roc: 0.1144 ms (0.0001 s)
# [+] rsi: 0.1217 ms (0.0001 s)
# [+] rsx: 6.2928 ms (0.0063 s)
# [+] rvgi: 4.0759 ms (0.0041 s)
# [+] rvi: 1.4748 ms (0.0015 s)
# [+] rwi: 0.7034 ms (0.0007 s)
# [+] short_run: 0.0012 ms (0.0000 s)
# [+] sinwma: 16.7935 ms (0.0168 s)
# [+] skew: 0.3936 ms (0.0004 s)
# [+] slope: 0.1543 ms (0.0002 s)
# [+] sma: 0.1322 ms (0.0001 s)
# [+] smi: 0.9507 ms (0.0010 s)
# [+] smma: 14.6568 ms (0.0147 s)
# [+] squeeze: 1.9718 ms (0.0020 s)
# [+] squeeze_pro: 3.3595 ms (0.0034 s)
# [+] ssf: 0.1400 ms (0.0001 s)
# [+] ssf3: 0.1282 ms (0.0001 s)
# [+] stc: 38.1158 ms (0.0381 s)
# [+] stdev: 0.2112 ms (0.0002 s)
# [+] stoch: 0.5241 ms (0.0005 s)
# [+] stochf: 0.4110 ms (0.0004 s)
# [+] stochrsi: 0.9426 ms (0.0009 s)
# [+] supertrend: 17.5296 ms (0.0175 s)
# [+] swma: 1.3342 ms (0.0013 s)
# [+] t3: 0.1748 ms (0.0002 s)
# [+] tema: 0.1432 ms (0.0001 s)
# [+] thermo: 1.0190 ms (0.0010 s)
# [+] tmo: 0.8775 ms (0.0009 s)
# [+] tos_stdevall: 1.5770 ms (0.0016 s)
# [+] trendflex: 0.1647 ms (0.0002 s)
# [+] trima: 0.1258 ms (0.0001 s)
# [+] trix: 0.7493 ms (0.0007 s)
# [+] true_range: 0.2955 ms (0.0003 s)
# [+] tsi: 0.6046 ms (0.0006 s)
# [+] tsignals: 0.0012 ms (0.0000 s)
# [+] ttm_trend: 1.1446 ms (0.0011 s)
# [+] ui: 0.4804 ms (0.0005 s)
# [+] uo: 0.2868 ms (0.0003 s)
# [+] variance: 0.1323 ms (0.0001 s)
# [+] vhf: 0.6500 ms (0.0007 s)
# [+] vhm: 0.6075 ms (0.0006 s)
# [+] vidya: 33.7498 ms (0.0337 s)
# [+] vortex: 0.8541 ms (0.0009 s)
# [+] vwap: 9.1787 ms (0.0092 s)
# [+] vwma: 0.3478 ms (0.0003 s)
# [+] wb_tsv: 1.6137 ms (0.0016 s)
# [+] wcp: 0.2640 ms (0.0003 s)
# [+] willr: 0.2671 ms (0.0003 s)
# [+] wma: 0.1156 ms (0.0001 s)
# [+] xsignals: 0.0013 ms (0.0000 s)
# [+] zlma: 0.2800 ms (0.0003 s)
# [+] zscore: 0.2717 ms (0.0003 s)
#
# ============================================================
#   Slowest 10 Indicators [155]
#   Observations[talib]: 1260
# ============================================================
#                  ms     secs
# Indicator
# qqe         77.5280  0.07753
# alligator   47.4284  0.04743
# psar        45.4192  0.04542
# stc         38.1158  0.03812
# vidya       33.7498  0.03375
# ebsw        32.8209  0.03282
# hilo        32.5812  0.03258
# jma         25.0673  0.02507
# supertrend  17.5296  0.01753
# sinwma      16.7935  0.01679
#
# ============================================================
# Time Stats:
#                ms      secs
# min      0.001000  0.000000
# 50%      0.505600  0.000510
# mean     3.608235  0.003608
# max     77.528000  0.077530
# total  559.276400  0.559250
#
# ============================================================

# %%
tal_speedsdf
# Out:
# <style type="text/css">
# #T_7d32d_row0_col0, #T_7d32d_row0_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_7d32d_row1_col0, #T_7d32d_row1_col1 {
#   background-color: #ff7e00;
#   color: #f1f1f1;
# }
# #T_7d32d_row2_col0, #T_7d32d_row2_col1 {
#   background-color: #ff8700;
#   color: #f1f1f1;
# }
# #T_7d32d_row3_col0, #T_7d32d_row3_col1 {
#   background-color: #ffa600;
#   color: #000000;
# }
# #T_7d32d_row4_col0, #T_7d32d_row4_col1 {
#   background-color: #ffb800;
#   color: #000000;
# }
# #T_7d32d_row5_col0, #T_7d32d_row5_col1 {
#   background-color: #ffbc00;
#   color: #000000;
# }
# #T_7d32d_row6_col0, #T_7d32d_row6_col1 {
#   background-color: #ffbd00;
#   color: #000000;
# }
# #T_7d32d_row7_col0, #T_7d32d_row7_col1 {
#   background-color: #ffdd00;
#   color: #000000;
# }
# #T_7d32d_row8_col0, #T_7d32d_row8_col1 {
#   background-color: #fffc00;
#   color: #000000;
# }
# #T_7d32d_row9_col0, #T_7d32d_row9_col1 {
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_7d32d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d32d_level0_col0" class="col_heading level0 col0" >ms</th>
#       <th id="T_7d32d_level0_col1" class="col_heading level0 col1" >secs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d32d_level0_row0" class="row_heading level0 row0" >qqe</th>
#       <td id="T_7d32d_row0_col0" class="data row0 col0" >77.528000</td>
#       <td id="T_7d32d_row0_col1" class="data row0 col1" >0.077530</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row1" class="row_heading level0 row1" >alligator</th>
#       <td id="T_7d32d_row1_col0" class="data row1 col0" >47.428400</td>
#       <td id="T_7d32d_row1_col1" class="data row1 col1" >0.047430</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row2" class="row_heading level0 row2" >psar</th>
#       <td id="T_7d32d_row2_col0" class="data row2 col0" >45.419200</td>
#       <td id="T_7d32d_row2_col1" class="data row2 col1" >0.045420</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row3" class="row_heading level0 row3" >stc</th>
#       <td id="T_7d32d_row3_col0" class="data row3 col0" >38.115800</td>
#       <td id="T_7d32d_row3_col1" class="data row3 col1" >0.038120</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row4" class="row_heading level0 row4" >vidya</th>
#       <td id="T_7d32d_row4_col0" class="data row4 col0" >33.749800</td>
#       <td id="T_7d32d_row4_col1" class="data row4 col1" >0.033750</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row5" class="row_heading level0 row5" >ebsw</th>
#       <td id="T_7d32d_row5_col0" class="data row5 col0" >32.820900</td>
#       <td id="T_7d32d_row5_col1" class="data row5 col1" >0.032820</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row6" class="row_heading level0 row6" >hilo</th>
#       <td id="T_7d32d_row6_col0" class="data row6 col0" >32.581200</td>
#       <td id="T_7d32d_row6_col1" class="data row6 col1" >0.032580</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row7" class="row_heading level0 row7" >jma</th>
#       <td id="T_7d32d_row7_col0" class="data row7 col0" >25.067300</td>
#       <td id="T_7d32d_row7_col1" class="data row7 col1" >0.025070</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row8" class="row_heading level0 row8" >supertrend</th>
#       <td id="T_7d32d_row8_col0" class="data row8 col0" >17.529600</td>
#       <td id="T_7d32d_row8_col1" class="data row8 col1" >0.017530</td>
#     </tr>
#     <tr>
#       <th id="T_7d32d_level0_row9" class="row_heading level0 row9" >sinwma</th>
#       <td id="T_7d32d_row9_col0" class="data row9 col0" >16.793500</td>
#       <td id="T_7d32d_row9_col1" class="data row9 col1" >0.016790</td>
#     </tr>
#   </tbody>
# </table>

# %%
tal_statsdf
# Out:
#                ms      secs
# min      0.001000  0.000000
# 50%      0.505600  0.000510
# mean     3.608235  0.003608
# max     77.528000  0.077530
# total  559.276400  0.559250

# %% [markdown]
# # Comparisons

# %%
print(df.shape)
compdf = concat([tal_statsdf, pta_statsdf], keys=["TA Lib", "Pandas TA"], axis=1).T
compdf
# Out:
# (1260, 8)
#                    min      50%      mean       max      total
# TA Lib    ms    0.0010  0.50560  3.608235  77.52800  559.27640
#           secs  0.0000  0.00051  0.003608   0.07753    0.55925
# Pandas TA ms    0.0011  0.85210  3.948935  76.14230  612.08500
#           secs  0.0000  0.00085  0.003949   0.07614    0.61210

# %%
diffdf = (tal_statsdf - pta_statsdf).abs().T
diffdf.columns.name = "Differences"
diffdf
# Out:
# Differences     min      50%      mean      max     total
# ms           0.0001  0.34650  0.340701  1.38570  52.80860
# secs         0.0000  0.00034  0.000341  0.00139   0.05285

# %% [markdown]
# ## Speed Comparison (ms)

# %%
taldf = ta.speed_test(df, places=10, talib=True, silent=True)["ms"]
ptadf = ta.speed_test(df, places=10, talib=False, silent=True)["ms"]

# %%
scdf = DataFrame({"TAL": taldf, "PTA": ptadf, "diff": taldf - ptadf})
scdf.round(decimals=3)
scdf.index.name = "Indicator (ms)"

# %%
scdf.sort_values(by=["TAL", "diff"], ascending=False, na_position="first", inplace=True)
scdf.style.background_gradient("autumn_r")
# Out:
# <style type="text/css">
# #T_de40a_row0_col0, #T_de40a_row0_col1, #T_de40a_row2_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_de40a_row0_col2, #T_de40a_row5_col2, #T_de40a_row14_col2, #T_de40a_row46_col2 {
#   background-color: #ff1f00;
#   color: #f1f1f1;
# }
# #T_de40a_row1_col0 {
#   background-color: #ff6300;
#   color: #f1f1f1;
# }
# #T_de40a_row1_col1, #T_de40a_row2_col0 {
#   background-color: #ff6700;
#   color: #f1f1f1;
# }
# #T_de40a_row1_col2 {
#   background-color: #ff0f00;
#   color: #f1f1f1;
# }
# #T_de40a_row2_col1 {
#   background-color: #ff6e00;
#   color: #f1f1f1;
# }
# #T_de40a_row3_col0 {
#   background-color: #ff8200;
#   color: #f1f1f1;
# }
# #T_de40a_row3_col1 {
#   background-color: #ff8300;
#   color: #f1f1f1;
# }
# #T_de40a_row3_col2 {
#   background-color: #ff1800;
#   color: #f1f1f1;
# }
# #T_de40a_row4_col0 {
#   background-color: #ff8d00;
#   color: #f1f1f1;
# }
# #T_de40a_row4_col1 {
#   background-color: #ff8a00;
#   color: #f1f1f1;
# }
# #T_de40a_row4_col2, #T_de40a_row136_col2 {
#   background-color: #ff3100;
#   color: #f1f1f1;
# }
# #T_de40a_row5_col0, #T_de40a_row5_col1 {
#   background-color: #ff9100;
#   color: #000000;
# }
# #T_de40a_row6_col0, #T_de40a_row6_col1 {
#   background-color: #ff9200;
#   color: #000000;
# }
# #T_de40a_row6_col2 {
#   background-color: #ff1d00;
#   color: #f1f1f1;
# }
# #T_de40a_row7_col0 {
#   background-color: #ffad00;
#   color: #000000;
# }
# #T_de40a_row7_col1 {
#   background-color: #ffae00;
#   color: #000000;
# }
# #T_de40a_row7_col2, #T_de40a_row8_col2, #T_de40a_row19_col2, #T_de40a_row47_col2, #T_de40a_row72_col2 {
#   background-color: #ff2000;
#   color: #f1f1f1;
# }
# #T_de40a_row8_col0, #T_de40a_row8_col1 {
#   background-color: #ffc600;
#   color: #000000;
# }
# #T_de40a_row9_col0 {
#   background-color: #ffc800;
#   color: #000000;
# }
# #T_de40a_row9_col1 {
#   background-color: #ffc700;
#   color: #000000;
# }
# #T_de40a_row9_col2, #T_de40a_row16_col2, #T_de40a_row105_col2, #T_de40a_row142_col2 {
#   background-color: #ff2500;
#   color: #f1f1f1;
# }
# #T_de40a_row10_col0 {
#   background-color: #ffc900;
#   color: #000000;
# }
# #T_de40a_row10_col1 {
#   background-color: #ffcc00;
#   color: #000000;
# }
# #T_de40a_row10_col2 {
#   background-color: #ff1700;
#   color: #f1f1f1;
# }
# #T_de40a_row11_col0 {
#   background-color: #ffce00;
#   color: #000000;
# }
# #T_de40a_row11_col1 {
#   background-color: #ffcd00;
#   color: #000000;
# }
# #T_de40a_row11_col2, #T_de40a_row12_col2, #T_de40a_row26_col2, #T_de40a_row56_col2, #T_de40a_row80_col2, #T_de40a_row89_col2, #T_de40a_row126_col2, #T_de40a_row146_col2, #T_de40a_row149_col2 {
#   background-color: #ff2400;
#   color: #f1f1f1;
# }
# #T_de40a_row12_col0, #T_de40a_row12_col1 {
#   background-color: #ffd500;
#   color: #000000;
# }
# #T_de40a_row13_col0, #T_de40a_row13_col1 {
#   background-color: #ffd800;
#   color: #000000;
# }
# #T_de40a_row13_col2, #T_de40a_row15_col2, #T_de40a_row17_col2, #T_de40a_row20_col2, #T_de40a_row30_col2, #T_de40a_row37_col2, #T_de40a_row38_col2, #T_de40a_row39_col2, #T_de40a_row41_col2, #T_de40a_row50_col2, #T_de40a_row63_col2 {
#   background-color: #ff2100;
#   color: #f1f1f1;
# }
# #T_de40a_row14_col0, #T_de40a_row14_col1 {
#   background-color: #ffe200;
#   color: #000000;
# }
# #T_de40a_row15_col0, #T_de40a_row15_col1 {
#   background-color: #ffe300;
#   color: #000000;
# }
# #T_de40a_row16_col0, #T_de40a_row17_col0, #T_de40a_row18_col0, #T_de40a_row18_col1 {
#   background-color: #ffea00;
#   color: #000000;
# }
# #T_de40a_row16_col1 {
#   background-color: #ffe900;
#   color: #000000;
# }
# #T_de40a_row17_col1 {
#   background-color: #ffeb00;
#   color: #000000;
# }
# #T_de40a_row18_col2, #T_de40a_row21_col2, #T_de40a_row27_col2, #T_de40a_row33_col2, #T_de40a_row34_col2, #T_de40a_row35_col2, #T_de40a_row48_col2, #T_de40a_row51_col2, #T_de40a_row52_col2, #T_de40a_row54_col2, #T_de40a_row55_col2, #T_de40a_row61_col2, #T_de40a_row64_col2, #T_de40a_row66_col2, #T_de40a_row67_col2, #T_de40a_row69_col2, #T_de40a_row70_col2, #T_de40a_row74_col2, #T_de40a_row76_col2, #T_de40a_row77_col2, #T_de40a_row81_col2, #T_de40a_row82_col2, #T_de40a_row86_col2, #T_de40a_row90_col2, #T_de40a_row92_col2, #T_de40a_row98_col2, #T_de40a_row102_col2, #T_de40a_row103_col2, #T_de40a_row107_col2, #T_de40a_row110_col2, #T_de40a_row112_col2, #T_de40a_row114_col2, #T_de40a_row115_col2, #T_de40a_row117_col2, #T_de40a_row120_col2, #T_de40a_row122_col2, #T_de40a_row127_col2, #T_de40a_row128_col2, #T_de40a_row130_col2, #T_de40a_row132_col2, #T_de40a_row134_col2, #T_de40a_row137_col2, #T_de40a_row140_col2, #T_de40a_row143_col2, #T_de40a_row150_col2, #T_de40a_row151_col2, #T_de40a_row152_col2, #T_de40a_row153_col2, #T_de40a_row154_col2 {
#   background-color: #ff2200;
#   color: #f1f1f1;
# }
# #T_de40a_row19_col0 {
#   background-color: #ffed00;
#   color: #000000;
# }
# #T_de40a_row19_col1, #T_de40a_row85_col1 {
#   background-color: #ffee00;
#   color: #000000;
# }
# #T_de40a_row20_col0, #T_de40a_row20_col1 {
#   background-color: #fff000;
#   color: #000000;
# }
# #T_de40a_row21_col0, #T_de40a_row21_col1 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_de40a_row22_col0, #T_de40a_row22_col1 {
#   background-color: #fff200;
#   color: #000000;
# }
# #T_de40a_row22_col2, #T_de40a_row23_col2, #T_de40a_row28_col2, #T_de40a_row29_col2, #T_de40a_row40_col2, #T_de40a_row42_col2, #T_de40a_row45_col2, #T_de40a_row49_col2, #T_de40a_row53_col2, #T_de40a_row59_col2, #T_de40a_row60_col2, #T_de40a_row65_col2, #T_de40a_row75_col2, #T_de40a_row84_col2, #T_de40a_row96_col2, #T_de40a_row97_col2, #T_de40a_row104_col2, #T_de40a_row106_col2, #T_de40a_row116_col2, #T_de40a_row123_col2, #T_de40a_row125_col2, #T_de40a_row139_col2, #T_de40a_row145_col2, #T_de40a_row148_col2 {
#   background-color: #ff2300;
#   color: #f1f1f1;
# }
# #T_de40a_row23_col0, #T_de40a_row23_col1, #T_de40a_row25_col1 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_de40a_row24_col0, #T_de40a_row58_col1 {
#   background-color: #fff800;
#   color: #000000;
# }
# #T_de40a_row24_col1, #T_de40a_row25_col0, #T_de40a_row26_col0, #T_de40a_row26_col1, #T_de40a_row27_col0, #T_de40a_row27_col1, #T_de40a_row28_col0, #T_de40a_row28_col1, #T_de40a_row29_col0, #T_de40a_row29_col1, #T_de40a_row32_col1, #T_de40a_row108_col1 {
#   background-color: #fff900;
#   color: #000000;
# }
# #T_de40a_row24_col2 {
#   background-color: #ff1e00;
#   color: #f1f1f1;
# }
# #T_de40a_row25_col2, #T_de40a_row68_col2, #T_de40a_row88_col2, #T_de40a_row101_col2 {
#   background-color: #ff2d00;
#   color: #f1f1f1;
# }
# #T_de40a_row30_col0, #T_de40a_row30_col1, #T_de40a_row31_col0, #T_de40a_row32_col0, #T_de40a_row33_col0, #T_de40a_row33_col1, #T_de40a_row34_col0, #T_de40a_row34_col1, #T_de40a_row62_col1, #T_de40a_row78_col1, #T_de40a_row79_col1, #T_de40a_row91_col1, #T_de40a_row109_col1 {
#   background-color: #fffa00;
#   color: #000000;
# }
# #T_de40a_row31_col1, #T_de40a_row44_col1, #T_de40a_row46_col1, #T_de40a_row52_col1, #T_de40a_row53_col0, #T_de40a_row53_col1, #T_de40a_row54_col0, #T_de40a_row54_col1, #T_de40a_row55_col0, #T_de40a_row55_col1, #T_de40a_row56_col0, #T_de40a_row56_col1, #T_de40a_row57_col0, #T_de40a_row58_col0, #T_de40a_row59_col0, #T_de40a_row59_col1, #T_de40a_row60_col0, #T_de40a_row60_col1, #T_de40a_row61_col0, #T_de40a_row61_col1, #T_de40a_row62_col0, #T_de40a_row63_col0, #T_de40a_row63_col1, #T_de40a_row64_col0, #T_de40a_row64_col1, #T_de40a_row65_col0, #T_de40a_row65_col1, #T_de40a_row66_col0, #T_de40a_row66_col1, #T_de40a_row67_col0, #T_de40a_row68_col0, #T_de40a_row69_col0, #T_de40a_row70_col0, #T_de40a_row70_col1, #T_de40a_row93_col1, #T_de40a_row111_col1, #T_de40a_row118_col1, #T_de40a_row119_col1, #T_de40a_row121_col1, #T_de40a_row129_col1, #T_de40a_row131_col1, #T_de40a_row141_col1, #T_de40a_row144_col1 {
#   background-color: #fffd00;
#   color: #000000;
# }
# #T_de40a_row31_col2 {
#   background-color: #ff1200;
#   color: #f1f1f1;
# }
# #T_de40a_row32_col2, #T_de40a_row95_col2, #T_de40a_row124_col2, #T_de40a_row138_col2, #T_de40a_row147_col2 {
#   background-color: #ff2600;
#   color: #f1f1f1;
# }
# #T_de40a_row35_col0, #T_de40a_row35_col1, #T_de40a_row36_col0, #T_de40a_row37_col0, #T_de40a_row37_col1, #T_de40a_row38_col0, #T_de40a_row38_col1, #T_de40a_row39_col0, #T_de40a_row39_col1, #T_de40a_row40_col0, #T_de40a_row40_col1,
