# %% [markdown]
# # Indicator Speed Test
#
# This Notebook shows the **Indicator Speed** with and without TA Lib
# * Results may vary if ```vectorbt``` or ```numba``` is installed.
# * These values are based on a M1 Macbook with 16GB Memory.

# %%
from importlib.util import find_spec

from numpy import version as numpy_version
from pandas import DataFrame, IndexSlice, concat, read_csv
from pandas import IndexSlice as idx
import pandas_ta as ta

print("Package Versions:")
print(f"Pandas TA v{ta.version}")

has_numba = find_spec("numba") is not None
if has_numba:
    from numba import __version__ as numba_version
    print(f"Numba v{numba_version}")
    
if find_spec("talib") is not None:
    from talib import __version__ as tal_version
    print(f"talib v{tal_version}")

from pandas import read_csv
from pandas import DatetimeIndex as dti
# %matplotlib inline
# Out:
# Package Versions:
# Pandas TA v0.3.67b0
# Numba v0.55.1
# talib v0.4.21

# %% [markdown]
# ### Fetch Sample Data

# %%
df = DataFrame()
_df = df.ta.ticker("SPY", period="5y", timed=True)
# Out:
# [+] yf | SPY(1258, 7): 5137.7390 ms (5.1377 s)

# %%
df = _df.copy()
df.shape
# Out:
# (1258, 7)

# %% [markdown]
# ### If ```numba``` installed, prep @njit functions
# * Some indicators like **ha** have numba/njit versions, so they need to be compiled by have a prerun. In the performance tests after this, **ha** and other numba/njit versions will be quicker also.

# %%
if has_numba:
    ta.speed_test(df.iloc[-150:], talib=False)
# Out:
# ============================================================
#   Slowest Indicators
#   Observations: 150
# ============================================================
#                        ms     secs
# Indicator
# alligator       1480.8412  1.48084
# mama             608.7813  0.60878
# atrts            394.1123  0.39411
# ha               217.1363  0.21714
# trendflex        215.9868  0.21599
# ...                   ...      ...
# percent_return     0.1629  0.00016
# tsignals           0.0014  0.00000
# xsignals           0.0016  0.00000
# long_run           0.0013  0.00000
# short_run          0.0015  0.00000
#
# [147 rows x 2 columns]
#
# ============================================================
# Time Stats:
#                 ms      secs
# min       0.001300  0.000000
# 50%       1.119100  0.001120
# mean     24.561661  0.024561
# max    1480.841200  1.480840
# total  3610.564200  3.610510
#
# ============================================================

# %% [markdown]
# ## Performance **without** TA Lib

# %%
pta_speedsdf, pta_statsdf = ta.speed_test(df, top=10, talib=False, stats=True, gradient=True, verbose=True)
# Out:
# [+] aberration: 1.0443 ms (0.0010 s)
# [+] accbands: 1.3986 ms (0.0014 s)
# [+] ad: 0.9993 ms (0.0010 s)
# [+] adosc: 1.6711 ms (0.0017 s)
# [+] adx: 3.6350 ms (0.0036 s)
# [+] alligator: 190.8575 ms (0.1909 s)
# [+] alma: 0.5293 ms (0.0005 s)
# [+] amat: 2.7036 ms (0.0027 s)
# [+] ao: 0.4914 ms (0.0005 s)
# [+] aobv: 4.1657 ms (0.0042 s)
# [+] apo: 1.0117 ms (0.0010 s)
# [+] aroon: 9.4737 ms (0.0095 s)
# [+] atr: 1.7186 ms (0.0017 s)
# [+] atrts: 2.0549 ms (0.0021 s)
# [+] bbands: 1.6208 ms (0.0016 s)
# [+] bias: 0.6449 ms (0.0006 s)
# [+] bop: 0.9181 ms (0.0009 s)
# [+] brar: 3.2632 ms (0.0033 s)
# [+] cci: 18.0862 ms (0.0181 s)
# [+] cdl_pattern: 8.9200 ms (0.0089 s)
# [+] cdl_z: 1.6618 ms (0.0017 s)
# [+] cfo: 0.3565 ms (0.0004 s)
# [+] cg: 9.7269 ms (0.0097 s)
# [+] chop: 1.2579 ms (0.0013 s)
# [+] cksp: 1.7376 ms (0.0017 s)
# [+] cmf: 1.2217 ms (0.0012 s)
# [+] cmo: 1.8574 ms (0.0019 s)
# [+] coppock: 0.3277 ms (0.0003 s)
# [+] cti: 18.0791 ms (0.0181 s)
# [+] cube: 0.6655 ms (0.0007 s)
# [+] decay: 0.5626 ms (0.0006 s)
# [+] decreasing: 0.3012 ms (0.0003 s)
# [+] dema: 0.7989 ms (0.0008 s)
# [+] dm: 2.1294 ms (0.0021 s)
# [+] donchian: 1.0200 ms (0.0010 s)
# [+] dpo: 0.4350 ms (0.0004 s)
# [+] ebsw: 40.2412 ms (0.0402 s)
# [+] efi: 0.3912 ms (0.0004 s)
# [+] ema: 0.3866 ms (0.0004 s)
# [+] entropy: 0.6362 ms (0.0006 s)
# [+] eom: 0.9676 ms (0.0010 s)
# [+] er: 0.4825 ms (0.0005 s)
# [+] eri: 0.6521 ms (0.0007 s)
# [+] fisher: 9.8256 ms (0.0098 s)
# [+] fwma: 2.7926 ms (0.0028 s)
# [+] ha: 0.5962 ms (0.0006 s)
# [+] hilo: 73.5913 ms (0.0736 s)
# [+] hl2: 0.2512 ms (0.0003 s)
# [+] hlc3: 0.3092 ms (0.0003 s)
# [+] hma: 0.3727 ms (0.0004 s)
# [+] hwc: 8.1451 ms (0.0081 s)
# [+] hwma: 7.5083 ms (0.0075 s)
# [+] ifisher: 0.6355 ms (0.0006 s)
# [+] increasing: 0.3224 ms (0.0003 s)
# [+] inertia: 2.6960 ms (0.0027 s)
# [+] jma: 30.4007 ms (0.0304 s)
# [+] kama: 17.8067 ms (0.0178 s)
# [+] kc: 1.0153 ms (0.0010 s)
# [+] kdj: 1.6227 ms (0.0016 s)
# [+] kst: 1.6288 ms (0.0016 s)
# [+] kurtosis: 0.3088 ms (0.0003 s)
# [+] kvo: 2.8716 ms (0.0029 s)
# [+] linreg: 12.1866 ms (0.0122 s)
# [+] log_return: 0.1969 ms (0.0002 s)
# [+] long_run: 0.0052 ms (0.0000 s)
# [+] macd: 2.2909 ms (0.0023 s)
# [+] mad: 14.4133 ms (0.0144 s)
# [+] mama: 0.4373 ms (0.0004 s)
# [+] massi: 1.3264 ms (0.0013 s)
# [+] mcgd: 2.2040 ms (0.0022 s)
# [+] median: 0.8689 ms (0.0009 s)
# [+] mfi: 3.3835 ms (0.0034 s)
# [+] midpoint: 0.5630 ms (0.0006 s)
# [+] midprice: 0.6437 ms (0.0006 s)
# [+] mom: 0.1786 ms (0.0002 s)
# [+] natr: 1.7602 ms (0.0018 s)
# [+] nvi: 1.4755 ms (0.0015 s)
# [+] obv: 0.9375 ms (0.0009 s)
# [+] ohlc4: 0.3922 ms (0.0004 s)
# [+] pdist: 1.2903 ms (0.0013 s)
# [+] percent_return: 0.1992 ms (0.0002 s)
# [+] pgo: 0.5908 ms (0.0006 s)
# [+] ppo: 1.6221 ms (0.0016 s)
# [+] psar: 92.4470 ms (0.0924 s)
# [+] psl: 0.9786 ms (0.0010 s)
# [+] pvi: 1.8801 ms (0.0019 s)
# [+] pvo: 0.7536 ms (0.0008 s)
# [+] pvol: 0.2625 ms (0.0003 s)
# [+] pvr: 1.2580 ms (0.0013 s)
# [+] pvt: 0.3505 ms (0.0004 s)
# [+] pwma: 2.1362 ms (0.0021 s)
# [+] qqe: 177.1798 ms (0.1772 s)
# [+] qstick: 0.8927 ms (0.0009 s)
# [+] quantile: 0.8617 ms (0.0009 s)
# [+] reflex: 0.2019 ms (0.0002 s)
# [+] remap: 0.1562 ms (0.0002 s)
# [+] rma: 0.2221 ms (0.0002 s)
# [+] roc: 0.3919 ms (0.0004 s)
# [+] rsi: 1.3156 ms (0.0013 s)
# [+] rsx: 10.7368 ms (0.0107 s)
# [+] rvgi: 7.9624 ms (0.0080 s)
# [+] rvi: 2.1463 ms (0.0021 s)
# [+] short_run: 0.0013 ms (0.0000 s)
# [+] sinwma: 10.7097 ms (0.0107 s)
# [+] skew: 0.3017 ms (0.0003 s)
# [+] slope: 0.2368 ms (0.0002 s)
# [+] sma: 0.4276 ms (0.0004 s)
# [+] smi: 1.2737 ms (0.0013 s)
# [+] smma: 63.7157 ms (0.0637 s)
# [+] squeeze: 3.1355 ms (0.0031 s)
# [+] squeeze_pro: 4.8081 ms (0.0048 s)
# [+] ssf: 0.1789 ms (0.0002 s)
# [+] ssf3: 0.1507 ms (0.0002 s)
# [+] stc: 23.6977 ms (0.0237 s)
# [+] stdev: 0.4310 ms (0.0004 s)
# [+] stoch: 2.4482 ms (0.0024 s)
# [+] stochf: 1.8246 ms (0.0018 s)
# [+] stochrsi: 1.3258 ms (0.0013 s)
# [+] supertrend: 55.5648 ms (0.0556 s)
# [+] swma: 2.2166 ms (0.0022 s)
# [+] t3: 2.0230 ms (0.0020 s)
# [+] td_seq: 775.4698 ms (0.7755 s)
# [+] tema: 1.3054 ms (0.0013 s)
# [+] thermo: 1.5458 ms (0.0015 s)
# [+] tos_stdevall: 2.6742 ms (0.0027 s)
# [+] trendflex: 0.2136 ms (0.0002 s)
# [+] trima: 0.8020 ms (0.0008 s)
# [+] trix: 1.7966 ms (0.0018 s)
# [+] true_range: 1.2989 ms (0.0013 s)
# [+] tsi: 1.8523 ms (0.0019 s)
# [+] tsignals: 0.0015 ms (0.0000 s)
# [+] ttm_trend: 1.7006 ms (0.0017 s)
# [+] ui: 1.0992 ms (0.0011 s)
# [+] uo: 2.9482 ms (0.0029 s)
# [+] variance: 0.3465 ms (0.0003 s)
# [+] vhf: 1.1136 ms (0.0011 s)
# [+] vidya: 47.2318 ms (0.0472 s)
# [+] vortex: 1.7507 ms (0.0018 s)
# [+] vwap: 1.9493 ms (0.0019 s)
# [+] vwma: 0.4346 ms (0.0004 s)
# [+] wb_tsv: 2.6122 ms (0.0026 s)
# [+] wcp: 0.3351 ms (0.0003 s)
# [+] willr: 0.9061 ms (0.0009 s)
# [+] wma: 10.7083 ms (0.0107 s)
# [+] xsignals: 0.0018 ms (0.0000 s)
# [+] zlma: 0.6438 ms (0.0006 s)
# [+] zscore: 0.9842 ms (0.0010 s)
#
# ============================================================
#   Slowest 10 Indicators [147]
#   Observations: 1258
# ============================================================
#                   ms     secs
# Indicator
# td_seq      775.4698  0.77547
# alligator   190.8575  0.19086
# qqe         177.1798  0.17718
# psar         92.4470  0.09245
# hilo         73.5913  0.07359
# smma         63.7157  0.06372
# supertrend   55.5648  0.05556
# vidya        47.2318  0.04723
# ebsw         40.2412  0.04024
# jma          30.4007  0.03040
#
# ============================================================
# Time Stats:
#                 ms      secs
# min       0.001300  0.000000
# 50%       1.290300  0.001290
# mean     12.851039  0.012851
# max     775.469800  0.775470
# total  1889.102700  1.889140
#
# ============================================================

# %%
pta_speedsdf
# Out:
# <style type="text/css">
# #T_621d4_row0_col0, #T_621d4_row0_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_621d4_row1_col0, #T_621d4_row1_col1 {
#   background-color: #ffc800;
#   color: #000000;
# }
# #T_621d4_row2_col0, #T_621d4_row2_col1 {
#   background-color: #ffcd00;
#   color: #000000;
# }
# #T_621d4_row3_col0, #T_621d4_row3_col1 {
#   background-color: #ffea00;
#   color: #000000;
# }
# #T_621d4_row4_col0, #T_621d4_row4_col1 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_621d4_row5_col0, #T_621d4_row5_col1 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_621d4_row6_col0, #T_621d4_row6_col1 {
#   background-color: #fff700;
#   color: #000000;
# }
# #T_621d4_row7_col0, #T_621d4_row7_col1 {
#   background-color: #fffa00;
#   color: #000000;
# }
# #T_621d4_row8_col0, #T_621d4_row8_col1 {
#   background-color: #fffc00;
#   color: #000000;
# }
# #T_621d4_row9_col0, #T_621d4_row9_col1 {
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_621d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_621d4_level0_col0" class="col_heading level0 col0" >ms</th>
#       <th id="T_621d4_level0_col1" class="col_heading level0 col1" >secs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_621d4_level0_row0" class="row_heading level0 row0" >td_seq</th>
#       <td id="T_621d4_row0_col0" class="data row0 col0" >775.469800</td>
#       <td id="T_621d4_row0_col1" class="data row0 col1" >0.775470</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row1" class="row_heading level0 row1" >alligator</th>
#       <td id="T_621d4_row1_col0" class="data row1 col0" >190.857500</td>
#       <td id="T_621d4_row1_col1" class="data row1 col1" >0.190860</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row2" class="row_heading level0 row2" >qqe</th>
#       <td id="T_621d4_row2_col0" class="data row2 col0" >177.179800</td>
#       <td id="T_621d4_row2_col1" class="data row2 col1" >0.177180</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row3" class="row_heading level0 row3" >psar</th>
#       <td id="T_621d4_row3_col0" class="data row3 col0" >92.447000</td>
#       <td id="T_621d4_row3_col1" class="data row3 col1" >0.092450</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row4" class="row_heading level0 row4" >hilo</th>
#       <td id="T_621d4_row4_col0" class="data row4 col0" >73.591300</td>
#       <td id="T_621d4_row4_col1" class="data row4 col1" >0.073590</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row5" class="row_heading level0 row5" >smma</th>
#       <td id="T_621d4_row5_col0" class="data row5 col0" >63.715700</td>
#       <td id="T_621d4_row5_col1" class="data row5 col1" >0.063720</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row6" class="row_heading level0 row6" >supertrend</th>
#       <td id="T_621d4_row6_col0" class="data row6 col0" >55.564800</td>
#       <td id="T_621d4_row6_col1" class="data row6 col1" >0.055560</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row7" class="row_heading level0 row7" >vidya</th>
#       <td id="T_621d4_row7_col0" class="data row7 col0" >47.231800</td>
#       <td id="T_621d4_row7_col1" class="data row7 col1" >0.047230</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row8" class="row_heading level0 row8" >ebsw</th>
#       <td id="T_621d4_row8_col0" class="data row8 col0" >40.241200</td>
#       <td id="T_621d4_row8_col1" class="data row8 col1" >0.040240</td>
#     </tr>
#     <tr>
#       <th id="T_621d4_level0_row9" class="row_heading level0 row9" >jma</th>
#       <td id="T_621d4_row9_col0" class="data row9 col0" >30.400700</td>
#       <td id="T_621d4_row9_col1" class="data row9 col1" >0.030400</td>
#     </tr>
#   </tbody>
# </table>

# %%
pta_statsdf
# Out:
#                 ms      secs
# min       0.001300  0.000000
# 50%       1.290300  0.001290
# mean     12.851039  0.012851
# max     775.469800  0.775470
# total  1889.102700  1.889140

# %% [markdown]
# ## Performance **with** TA Lib

# %%
tal_speedsdf, tal_statsdf = ta.speed_test(df, top=10, talib=True, stats=True, gradient=True, verbose=True)
# Out:
# [+] aberration: 1.3248 ms (0.0013 s)
# [+] accbands: 1.7619 ms (0.0018 s)
# [+] ad: 0.4845 ms (0.0005 s)
# [+] adosc: 0.4322 ms (0.0004 s)
# [+] adx: 3.3500 ms (0.0033 s)
# [+] alligator: 192.9943 ms (0.1930 s)
# [+] alma: 0.4785 ms (0.0005 s)
# [+] amat: 2.1157 ms (0.0021 s)
# [+] ao: 0.4729 ms (0.0005 s)
# [+] aobv: 2.8206 ms (0.0028 s)
# [+] apo: 0.1843 ms (0.0002 s)
# [+] aroon: 0.5705 ms (0.0006 s)
# [+] atr: 0.5253 ms (0.0005 s)
# [+] atrts: 0.5326 ms (0.0005 s)
# [+] bbands: 0.8853 ms (0.0009 s)
# [+] bias: 0.2736 ms (0.0003 s)
# [+] bop: 0.4107 ms (0.0004 s)
# [+] brar: 3.6687 ms (0.0037 s)
# [+] cci: 0.4883 ms (0.0005 s)
# [+] cdl_pattern: 9.6104 ms (0.0096 s)
# [+] cdl_z: 1.5855 ms (0.0016 s)
# [+] cfo: 0.3546 ms (0.0004 s)
# [+] cg: 9.7216 ms (0.0097 s)
# [+] chop: 1.2316 ms (0.0012 s)
# [+] cksp: 1.5184 ms (0.0015 s)
# [+] cmf: 1.2443 ms (0.0012 s)
# [+] cmo: 0.1891 ms (0.0002 s)
# [+] coppock: 0.3030 ms (0.0003 s)
# [+] cti: 17.9459 ms (0.0179 s)
# [+] cube: 0.5800 ms (0.0006 s)
# [+] decay: 0.8747 ms (0.0009 s)
# [+] decreasing: 0.3117 ms (0.0003 s)
# [+] dema: 0.1854 ms (0.0002 s)
# [+] dm: 1.2984 ms (0.0013 s)
# [+] donchian: 0.9874 ms (0.0010 s)
# [+] dpo: 0.4272 ms (0.0004 s)
# [+] ebsw: 39.6651 ms (0.0397 s)
# [+] efi: 0.3852 ms (0.0004 s)
# [+] ema: 0.1541 ms (0.0002 s)
# [+] entropy: 0.6816 ms (0.0007 s)
# [+] eom: 0.9300 ms (0.0009 s)
# [+] er: 0.4759 ms (0.0005 s)
# [+] eri: 0.6449 ms (0.0006 s)
# [+] fisher: 9.8537 ms (0.0099 s)
# [+] fwma: 2.4304 ms (0.0024 s)
# [+] ha: 0.6150 ms (0.0006 s)
# [+] hilo: 73.1630 ms (0.0732 s)
# [+] hl2: 0.2606 ms (0.0003 s)
# [+] hlc3: 0.4053 ms (0.0004 s)
# [+] hma: 0.3757 ms (0.0004 s)
# [+] hwc: 8.2824 ms (0.0083 s)
# [+] hwma: 7.2877 ms (0.0073 s)
# [+] ifisher: 0.6631 ms (0.0007 s)
# [+] increasing: 0.3110 ms (0.0003 s)
# [+] inertia: 2.0750 ms (0.0021 s)
# [+] jma: 29.7408 ms (0.0297 s)
# [+] kama: 18.6430 ms (0.0186 s)
# [+] kc: 1.0675 ms (0.0011 s)
# [+] kdj: 1.7999 ms (0.0018 s)
# [+] kst: 1.6214 ms (0.0016 s)
# [+] kurtosis: 0.2774 ms (0.0003 s)
# [+] kvo: 2.4393 ms (0.0024 s)
# [+] linreg: 0.1832 ms (0.0002 s)
# [+] log_return: 0.1817 ms (0.0002 s)
# [+] long_run: 0.0014 ms (0.0000 s)
# [+] macd: 1.3021 ms (0.0013 s)
# [+] mad: 14.6163 ms (0.0146 s)
# [+] mama: 0.4629 ms (0.0005 s)
# [+] massi: 0.8881 ms (0.0009 s)
# [+] mcgd: 2.2678 ms (0.0023 s)
# [+] median: 0.8979 ms (0.0009 s)
# [+] mfi: 0.4301 ms (0.0004 s)
# [+] midpoint: 0.1557 ms (0.0002 s)
# [+] midprice: 0.2315 ms (0.0002 s)
# [+] mom: 0.1428 ms (0.0001 s)
# [+] natr: 0.3155 ms (0.0003 s)
# [+] nvi: 1.6863 ms (0.0017 s)
# [+] obv: 0.2431 ms (0.0002 s)
# [+] ohlc4: 0.3727 ms (0.0004 s)
# [+] pdist: 1.2221 ms (0.0012 s)
# [+] percent_return: 0.1708 ms (0.0002 s)
# [+] pgo: 0.5595 ms (0.0006 s)
# [+] ppo: 0.5053 ms (0.0005 s)
# [+] psar: 92.9833 ms (0.0930 s)
# [+] psl: 1.0264 ms (0.0010 s)
# [+] pvi: 1.7646 ms (0.0018 s)
# [+] pvo: 0.7638 ms (0.0008 s)
# [+] pvol: 0.2694 ms (0.0003 s)
# [+] pvr: 1.2738 ms (0.0013 s)
# [+] pvt: 0.3537 ms (0.0004 s)
# [+] pwma: 2.2113 ms (0.0022 s)
# [+] qqe: 180.2017 ms (0.1802 s)
# [+] qstick: 0.6006 ms (0.0006 s)
# [+] quantile: 0.9070 ms (0.0009 s)
# [+] reflex: 0.2055 ms (0.0002 s)
# [+] remap: 0.1569 ms (0.0002 s)
# [+] rma: 0.2193 ms (0.0002 s)
# [+] roc: 0.1558 ms (0.0002 s)
# [+] rsi: 0.1592 ms (0.0002 s)
# [+] rsx: 10.8001 ms (0.0108 s)
# [+] rvgi: 7.8520 ms (0.0079 s)
# [+] rvi: 2.1991 ms (0.0022 s)
# [+] short_run: 0.0013 ms (0.0000 s)
# [+] sinwma: 11.0592 ms (0.0111 s)
# [+] skew: 0.3456 ms (0.0003 s)
# [+] slope: 0.2365 ms (0.0002 s)
# [+] sma: 0.1526 ms (0.0002 s)
# [+] smi: 1.2568 ms (0.0013 s)
# [+] smma: 63.5334 ms (0.0635 s)
# [+] squeeze: 2.9606 ms (0.0030 s)
# [+] squeeze_pro: 4.7419 ms (0.0047 s)
# [+] ssf: 0.1717 ms (0.0002 s)
# [+] ssf3: 0.1491 ms (0.0001 s)
# [+] stc: 23.6454 ms (0.0236 s)
# [+] stdev: 0.1693 ms (0.0002 s)
# [+] stoch: 0.6287 ms (0.0006 s)
# [+] stochf: 1.3942 ms (0.0014 s)
# [+] stochrsi: 1.4100 ms (0.0014 s)
# [+] supertrend: 55.5398 ms (0.0555 s)
# [+] swma: 1.9571 ms (0.0020 s)
# [+] t3: 0.1812 ms (0.0002 s)
# [+] td_seq: 774.2967 ms (0.7743 s)
# [+] tema: 0.2508 ms (0.0003 s)
# [+] thermo: 1.3973 ms (0.0014 s)
# [+] tos_stdevall: 2.7363 ms (0.0027 s)
# [+] trendflex: 0.2043 ms (0.0002 s)
# [+] trima: 0.1704 ms (0.0002 s)
# [+] trix: 1.0806 ms (0.0011 s)
# [+] true_range: 0.3815 ms (0.0004 s)
# [+] tsi: 0.9176 ms (0.0009 s)
# [+] tsignals: 0.0016 ms (0.0000 s)
# [+] ttm_trend: 1.7595 ms (0.0018 s)
# [+] ui: 0.9529 ms (0.0010 s)
# [+] uo: 0.3700 ms (0.0004 s)
# [+] variance: 0.1513 ms (0.0002 s)
# [+] vhf: 1.1960 ms (0.0012 s)
# [+] vidya: 48.3932 ms (0.0484 s)
# [+] vortex: 1.7335 ms (0.0017 s)
# [+] vwap: 1.9742 ms (0.0020 s)
# [+] vwma: 0.4285 ms (0.0004 s)
# [+] wb_tsv: 2.4541 ms (0.0025 s)
# [+] wcp: 0.3376 ms (0.0003 s)
# [+] willr: 0.3276 ms (0.0003 s)
# [+] wma: 0.1443 ms (0.0001 s)
# [+] xsignals: 0.0016 ms (0.0000 s)
# [+] zlma: 0.3807 ms (0.0004 s)
# [+] zscore: 0.3473 ms (0.0003 s)
#
# ============================================================
#   Slowest 10 Indicators [147]
#   Observations[talib]: 1258
# ============================================================
#                   ms     secs
# Indicator
# td_seq      774.2967  0.77430
# alligator   192.9943  0.19299
# qqe         180.2017  0.18020
# psar         92.9833  0.09298
# hilo         73.1630  0.07316
# smma         63.5334  0.06353
# supertrend   55.5398  0.05554
# vidya        48.3932  0.04839
# ebsw         39.6651  0.03967
# jma          29.7408  0.02974
#
# ============================================================
# Time Stats:
#                 ms      secs
# min       0.001300  0.000000
# 50%       0.663100  0.000660
# mean     12.307871  0.012308
# max     774.296700  0.774300
# total  1809.257000  1.809240
#
# ============================================================

# %%
tal_speedsdf
# Out:
# <style type="text/css">
# #T_045f2_row0_col0, #T_045f2_row0_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_045f2_row1_col0, #T_045f2_row1_col1 {
#   background-color: #ffc700;
#   color: #000000;
# }
# #T_045f2_row2_col0, #T_045f2_row2_col1 {
#   background-color: #ffcc00;
#   color: #000000;
# }
# #T_045f2_row3_col0, #T_045f2_row3_col1 {
#   background-color: #ffea00;
#   color: #000000;
# }
# #T_045f2_row4_col0, #T_045f2_row4_col1 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_045f2_row5_col0, #T_045f2_row5_col1 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_045f2_row6_col0, #T_045f2_row6_col1 {
#   background-color: #fff700;
#   color: #000000;
# }
# #T_045f2_row7_col0, #T_045f2_row7_col1 {
#   background-color: #fff900;
#   color: #000000;
# }
# #T_045f2_row8_col0, #T_045f2_row8_col1 {
#   background-color: #fffc00;
#   color: #000000;
# }
# #T_045f2_row9_col0, #T_045f2_row9_col1 {
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_045f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_045f2_level0_col0" class="col_heading level0 col0" >ms</th>
#       <th id="T_045f2_level0_col1" class="col_heading level0 col1" >secs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_045f2_level0_row0" class="row_heading level0 row0" >td_seq</th>
#       <td id="T_045f2_row0_col0" class="data row0 col0" >774.296700</td>
#       <td id="T_045f2_row0_col1" class="data row0 col1" >0.774300</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row1" class="row_heading level0 row1" >alligator</th>
#       <td id="T_045f2_row1_col0" class="data row1 col0" >192.994300</td>
#       <td id="T_045f2_row1_col1" class="data row1 col1" >0.192990</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row2" class="row_heading level0 row2" >qqe</th>
#       <td id="T_045f2_row2_col0" class="data row2 col0" >180.201700</td>
#       <td id="T_045f2_row2_col1" class="data row2 col1" >0.180200</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row3" class="row_heading level0 row3" >psar</th>
#       <td id="T_045f2_row3_col0" class="data row3 col0" >92.983300</td>
#       <td id="T_045f2_row3_col1" class="data row3 col1" >0.092980</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row4" class="row_heading level0 row4" >hilo</th>
#       <td id="T_045f2_row4_col0" class="data row4 col0" >73.163000</td>
#       <td id="T_045f2_row4_col1" class="data row4 col1" >0.073160</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row5" class="row_heading level0 row5" >smma</th>
#       <td id="T_045f2_row5_col0" class="data row5 col0" >63.533400</td>
#       <td id="T_045f2_row5_col1" class="data row5 col1" >0.063530</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row6" class="row_heading level0 row6" >supertrend</th>
#       <td id="T_045f2_row6_col0" class="data row6 col0" >55.539800</td>
#       <td id="T_045f2_row6_col1" class="data row6 col1" >0.055540</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row7" class="row_heading level0 row7" >vidya</th>
#       <td id="T_045f2_row7_col0" class="data row7 col0" >48.393200</td>
#       <td id="T_045f2_row7_col1" class="data row7 col1" >0.048390</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row8" class="row_heading level0 row8" >ebsw</th>
#       <td id="T_045f2_row8_col0" class="data row8 col0" >39.665100</td>
#       <td id="T_045f2_row8_col1" class="data row8 col1" >0.039670</td>
#     </tr>
#     <tr>
#       <th id="T_045f2_level0_row9" class="row_heading level0 row9" >jma</th>
#       <td id="T_045f2_row9_col0" class="data row9 col0" >29.740800</td>
#       <td id="T_045f2_row9_col1" class="data row9 col1" >0.029740</td>
#     </tr>
#   </tbody>
# </table>

# %%
tal_statsdf
# Out:
#                 ms      secs
# min       0.001300  0.000000
# 50%       0.663100  0.000660
# mean     12.307871  0.012308
# max     774.296700  0.774300
# total  1809.257000  1.809240

# %% [markdown]
# # Comparisons

# %%
print(df.shape)
compdf = concat([tal_statsdf, pta_statsdf], keys=["TA Lib", "Pandas TA"], axis=1).T
compdf
# Out:
# (1258, 7)
#                    min      50%       mean        max       total
# TA Lib    ms    0.0013  0.66310  12.307871  774.29670  1809.25700
#           secs  0.0000  0.00066   0.012308    0.77430     1.80924
# Pandas TA ms    0.0013  1.29030  12.851039  775.46980  1889.10270
#           secs  0.0000  0.00129   0.012851    0.77547     1.88914

# %%
diffdf = (tal_statsdf - pta_statsdf).abs().T
diffdf.columns.name = "Differences"
diffdf
# Out:
# Differences  min      50%      mean      max    total
# ms           0.0  0.62720  0.543168  1.17310  79.8457
# secs         0.0  0.00063  0.000544  0.00117   0.0799
